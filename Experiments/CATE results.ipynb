# %%
import numpy as np
import pandas as pd

# %%
ihdp_results = pd.read_csv('ihdp_CATE_results.csv')

# %%
round(ihdp_results.groupby(['gen_type', 'learner']).mean(), 3)
# Out:
# /tmp/ipykernel_734466/2785684816.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   round(ihdp_results.groupby(['gen_type', 'learner']).mean(), 3)
#                    rmse
# gen_type learner
# arf      DRNet()  2.918
#          PWNet()  3.470
#          RANet()  2.736
#          SNet()   3.171
#          TNet()   2.737
# ctgan    DRNet()  3.662
#          PWNet()  5.523
#          RANet()  2.512
#          SNet()   3.028
#          TNet()   2.551
# ddpm     DRNet()  2.680
#          PWNet()  3.846
#          RANet()  1.957
#          SNet()   2.498
#          TNet()   2.004
# nflow    DRNet()  4.253
#          PWNet()  6.346
#          RANet()  3.909
#          SNet()   4.826
#          TNet()   3.822
# real     DRNet()  0.704
#          PWNet()  1.750
#          RANet()  0.559
# ...

# %%
round(ihdp_results.groupby(['gen_type', 'learner']).std(),3)
# Out:
# /tmp/ipykernel_734466/2934920463.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   round(ihdp_results.groupby(['gen_type', 'learner']).std(),3)
#                    rmse
# gen_type learner
# arf      DRNet()  0.601
#          PWNet()  0.792
#          RANet()  0.565
#          SNet()   0.726
#          TNet()   0.533
# ctgan    DRNet()  2.640
#          PWNet()  4.356
#          RANet()  0.843
#          SNet()   0.348
#          TNet()   0.836
# ddpm     DRNet()  1.073
#          PWNet()  0.926
#          RANet()  0.310
#          SNet()   0.396
#          TNet()   0.402
# nflow    DRNet()  1.076
#          PWNet()  2.653
#          RANet()  1.259
#          SNet()   0.841
#          TNet()   1.284
# real     DRNet()    NaN
#          PWNet()    NaN
#          RANet()    NaN
# ...

# %%
acic_results = pd.read_csv('acic_CATE_results.csv')

# %%
round(acic_results.groupby(['gen_type', 'learner']).mean(), 3)
# Out:
# /tmp/ipykernel_734466/1882807954.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   round(acic_results.groupby(['gen_type', 'learner']).mean(), 3)
#                     rmse
# gen_type learner
# arf      DRNet()   4.376
#          PWNet()   6.644
#          RANet()   4.344
#          TNet()    4.320
# ctgan    DRNet()   4.430
#          PWNet()   4.995
#          RANet()   4.768
#          TNet()    5.280
# ddpm     DRNet()   7.874
#          PWNet()   5.425
#          RANet()  10.835
#          TNet()   10.878
# nflow    DRNet()   4.812
#          PWNet()   5.340
#          RANet()   5.145
#          TNet()    4.818
# real     DRNet()   2.445
#          PWNet()   5.084
#          RANet()   1.824
#          TNet()    2.033
# tvae     DRNet()   4.218
#          PWNet()   5.439
# ...

# %%
round(acic_results.groupby(['gen_type', 'learner']).std(), 3)
# Out:
# /tmp/ipykernel_734466/2199754328.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   round(acic_results.groupby(['gen_type', 'learner']).std(), 3)
#                    rmse
# gen_type learner
# arf      DRNet()  0.723
#          PWNet()  1.941
#          RANet()  0.403
#          TNet()   0.426
# ctgan    DRNet()  0.714
#          PWNet()  1.185
#          RANet()  0.362
#          TNet()   0.567
# ddpm     DRNet()  4.179
#          PWNet()  1.198
#          RANet()  7.389
#          TNet()   6.220
# nflow    DRNet()  0.584
#          PWNet()  0.644
#          RANet()  0.414
#          TNet()   0.403
# real     DRNet()    NaN
#          PWNet()    NaN
#          RANet()    NaN
#          TNet()     NaN
# tvae     DRNet()  0.078
#          PWNet()  1.669
#          RANet()  0.328
# ...

# %%
ihdp_standard_metrics = pd.read_csv('ihdp_standard_metrics.csv', index_col = 0)

# %%
ihdp_standard_metrics['gen'] = [i.split('_')[0] for i in ihdp_standard_metrics['dataset']]

# %%
ihdp_standard_metrics[ihdp_standard_metrics['metric']=='marginal'].sort_values(by='result')
# Out:
#               dataset    metric    result    gen
# 42    tvae_ihdp_4.csv  marginal  0.874176   tvae
# 0     tvae_ihdp_0.csv  marginal  0.899094   tvae
# 154   tvae_ihdp_1.csv  marginal  0.899419   tvae
# 35    ddpm_ihdp_2.csv  marginal  0.909155   ddpm
# 56    tvae_ihdp_3.csv  marginal  0.909288   tvae
# 70    ddpm_ihdp_0.csv  marginal  0.909501   ddpm
# 14    ddpm_ihdp_1.csv  marginal  0.913110   ddpm
# 98    tvae_ihdp_2.csv  marginal  0.915658   tvae
# 140   ddpm_ihdp_4.csv  marginal  0.921438   ddpm
# 49    ddpm_ihdp_3.csv  marginal  0.922791   ddpm
# 126  ctgan_ihdp_3.csv  marginal  0.934570  ctgan
# 168  ctgan_ihdp_1.csv  marginal  0.936313  ctgan
# 7    ctgan_ihdp_4.csv  marginal  0.944880  ctgan
# 21   ctgan_ihdp_0.csv  marginal  0.946777  ctgan
# 119  nflow_ihdp_4.csv  marginal  0.966146  nflow
# 147  ctgan_ihdp_2.csv  marginal  0.966483  ctgan
# 105  nflow_ihdp_1.csv  marginal  0.968525  nflow
# 133  nflow_ihdp_0.csv  marginal  0.970535  nflow
# ...

# %%
round(ihdp_standard_metrics[ihdp_standard_metrics['metric']=='marginal'].groupby('gen').mean().sort_values(by='result'), 3)
# Out:
# /tmp/ipykernel_1027210/3429467271.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   round(ihdp_standard_metrics[ihdp_standard_metrics['metric']=='marginal'].groupby('gen').mean().sort_values(by='result'), 3)
#        result
# gen
# tvae    0.900
# ddpm    0.915
# ctgan   0.946
# nflow   0.971
# arf     0.989

# %%
round(ihdp_standard_metrics[ihdp_standard_metrics['metric']=='delta_precision_alpha_OC'].groupby('gen').mean().sort_values(by='result'),3)
# Out:
# /tmp/ipykernel_1027210/175794599.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   round(ihdp_standard_metrics[ihdp_standard_metrics['metric']=='delta_precision_alpha_OC'].groupby('gen').mean().sort_values(by='result'),3)
#        result
# gen
# nflow   0.231
# arf     0.353
# tvae    0.431
# ctgan   0.432
# ddpm    0.516

# %%
round(ihdp_standard_metrics[ihdp_standard_metrics['metric']=='delta_coverage_beta_OC'].groupby('gen').mean().sort_values(by='result'), 3)
# Out:
# /tmp/ipykernel_1027210/3966152869.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   round(ihdp_standard_metrics[ihdp_standard_metrics['metric']=='delta_coverage_beta_OC'].groupby('gen').mean().sort_values(by='result'), 3)
#        result
# gen
# nflow   0.162
# arf     0.254
# ctgan   0.292
# tvae    0.319
# ddpm    0.335

# %%
acic_standard_metrics = pd.read_csv('acic_standard_metrics.csv')

# %%
acic_standard_metrics['gen'] = [i.split('_')[0] for i in acic_standard_metrics['dataset']]

# %%
round(acic_standard_metrics[acic_standard_metrics['metric']=='marginal'].groupby('gen').mean().sort_values(by='result'), 3)
# Out:
# /tmp/ipykernel_1027210/2594636950.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   round(acic_standard_metrics[acic_standard_metrics['metric']=='marginal'].groupby('gen').mean().sort_values(by='result'), 3)
#        result
# gen
# ddpm    0.623
# tvae    0.917
# nflow   0.920
# ctgan   0.968
# arf     0.984

# %%
round(acic_standard_metrics[acic_standard_metrics['metric']=='delta_precision_alpha_OC'].groupby('gen').mean().sort_values(by='result'), 3)
# Out:
# /tmp/ipykernel_1027210/1207424363.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   round(acic_standard_metrics[acic_standard_metrics['metric']=='delta_precision_alpha_OC'].groupby('gen').mean().sort_values(by='result'), 3)
#        result
# gen
# ddpm    0.136
# nflow   0.693
# arf     0.781
# ctgan   0.863
# tvae    0.966

# %%
round(acic_standard_metrics[acic_standard_metrics['metric']=='delta_coverage_beta_OC'].groupby('gen').mean().sort_values(by='result'), 3)
# Out:
# /tmp/ipykernel_1027210/1585378624.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   round(acic_standard_metrics[acic_standard_metrics['metric']=='delta_coverage_beta_OC'].groupby('gen').mean().sort_values(by='result'), 3)
#        result
# gen
# ddpm    0.002
# nflow   0.325
# arf     0.432
# ctgan   0.439
# tvae    0.493
